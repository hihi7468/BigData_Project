# %% [markdown]
# <블로그> 크롤링

# %%
import requests
from urllib.parse import urlparse
import csv

def get_api_result(keyword, display, start):
    url = "https://openapi.naver.com/v1/search/blog?query="+ keyword +"&display=" + str(display_count) +"&start=" + str(start)
    result = requests. get(urlparse(url). geturl(),
                           headers= {"X-Naver-Client-Id":"Fid_LQiP9j9aM7e4KWpE",
                                     "X-Naver-Client-Secret":"6IxM7NZWFK"})
    return result. json()



def call_and_print(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
#     print(json_obj)
    i=1
    for item in json_obj['items']:
        title = item['title']. replace("<b>",""). replace("</b>","")
        print(i,'====>', title + "@"
              + item["bloggername"] + "@"
              + item["postdate"] + "@"
              + item["link"])
        i = i+1
        
def call_and_csv_write(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
    print(json_obj)
    for item in json_obj["items"]:
        title = item['title'].replace("<b>","").replace("</b>","")
        wr. writerow([title, item["bloggername"],item["postdate"], item["link"] ])
        
        
keyword = input("검색어를 입력하시오. ")

start_point = int(input("시작 포인트를 입력하시오. "))
display_count = int(input("한번에 추출하고자 하는 결괏값 수를 입력하시오. "))

repeat_times = int(input("결과 추출을 반복할 횟수를 입력하시오. "))


#======== 출력하기 =======

f = open('blog_api.csv', 'w', encoding = 'utf-8-sig', newline='')
wr = csv.writer(f)

for cnt in range(1,repeat_times+1):
    print('--- { count } ---------', cnt)
    call_and_print(keyword,display_count,start_point)
    call_and_csv_write(keyword, display_count, start_point)
    start_point += display_count

f.close()
json_obj = get_api_result(keyword, display_count, start_point)

#--------------------------------------------------------------


f = open('junyoung.csv', 'r', encoding = 'utf-8-sig', newline='')
rdr = csv.reader(f)
cnt = 0

for line in rdr:
    cnt += 1
    
print('count: ', cnt)
f.close()
# Out:
# 검색어를 입력하시오. 코로나
# 시작 포인트를 입력하시오. 1
# 한번에 추출하고자 하는 결괏값 수를 입력하시오. 2
# 결과 추출을 반복할 횟수를 입력하시오. 2
# --- { count } --------- 1
# 1 ====> 코로나 확진자 재택치료 기간 1-5일차 일기@고디공간만의 트랜디함을 담아, 고디자인스튜디오@20220203@https://blog.naver.com/daheeprint?Redirect=Log&logNo=222637784239
# 2 ====> 코로나 방역 대표업체 신뢰하고 맡긴 후기@욕실119@20220203@https://blog.naver.com/qkrkekdz?Redirect=Log&logNo=222638042481
# ...

# %% [markdown]
# <지식인> 크롤링

# %%
import requests
from urllib.parse import urlparse
import csv

def get_api_result(keyword, display, start):
    url = "https://openapi.naver.com/v1/search/kin?query="+ keyword +"&display=" + str(display_count) +"&start=" + str(start)
    result = requests. get(urlparse(url). geturl(),
                           headers= {"X-Naver-Client-Id":"Fid_LQiP9j9aM7e4KWpE",
                                     "X-Naver-Client-Secret":"6IxM7NZWFK"})
    return result. json()



def call_and_print(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
#     print(json_obj)
    i=1
    for item in json_obj['items']:
        title = item['title']. replace("<b>",""). replace("</b>","")
        print(i,'====>', title + "@"+ item["link"] + "@"+ item["description"])
        i = i+1
        
def call_and_csv_write(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
    print(json_obj)
    for item in json_obj["items"]:
        title = item['title'].replace("<b>","").replace("</b>","")
        wr. writerow([title, item["link"], item["description"].replace("<b>","").replace("</b>","").replace("&lt;","<").replace("&gt;",">")])
        
        
keyword = input("검색어를 입력하시오. ")

start_point = int(input("시작 포인트를 입력하시오. "))
display_count = int(input("한번에 추출하고자 하는 결괏값 수를 입력하시오. "))

repeat_times = int(input("결과 추출을 반복할 횟수를 입력하시오. "))


#======== 출력하기 =======

f = open('kin_api.csv', 'w', encoding = 'utf-8-sig', newline='')
wr = csv.writer(f)

for cnt in range(1,repeat_times+1):
    print('--- { count } ---------', cnt)
    call_and_print(keyword,display_count,start_point)
    call_and_csv_write(keyword, display_count, start_point)
    start_point += display_count

f.close()
json_obj = get_api_result(keyword, display_count, start_point)

#--------------------------------------------------------------


f = open('kin_api.csv', 'r', encoding = 'utf-8-sig', newline='')
rdr = csv.reader(f)
cnt = 0

for line in rdr:
    cnt += 1
    
print('count: ', cnt)
f.close()
# Out:
# 검색어를 입력하시오. 코로나
# 시작 포인트를 입력하시오. 1
# 한번에 추출하고자 하는 결괏값 수를 입력하시오. 2
# 결과 추출을 반복할 횟수를 입력하시오. 2
# --- { count } --------- 1
# 1 ====> 코로나 감기 구별법@https://kin.naver.com/qna/detail.naver?d1id=7&dirId=70306&docId=410268881&qb=7L2U66Gc64KY&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0@<b>코로나</b>랑 감기 구별법 알려주세요 시간이 없어서 <b>코로나</b> 검사를 하기는 좀 그런데 최근에 날씨가 추워지기도 했고... 있는것같은데 <b>코로나</b>인지 감기인지 확실한 구별법... 증상으로 감기와 <b>코로나</b>를 구별하는 것은 적절하지 않으며...
# 2 ====> 코로나 음성 문자@https://kin.naver.com/qna/detail.naver?d1id=7&dirId=7010105&docId=409303075&qb=7L2U66Gc64KY&enc=utf8&section=kin.qna&rank=2&search_sort=0&spq=0@아빠랑 <b>코로나</b> 검사 같이 받으러 갔는데 아빠는 음성 문자가 왔는데 전 안... #<b>코로나</b> #<b>코로나</b>검사  안녕하세요. 서울생활 행복도우미 120다산콜센터... ◈ 자치구 선별진료소 및 임시선별진료소에서 <b>코로나</b> 검사를 받으셨다면...
# ...

# %%
<책> 크롤링

# %%
import requests
from urllib.parse import urlparse
import csv

def get_api_result(keyword, display, start):
    url = "https://openapi.naver.com/v1/search/book?query="+ keyword +"&display=" + str(display_count) +"&start=" + str(start)
    result = requests. get(urlparse(url). geturl(),
                           headers= {"X-Naver-Client-Id":"Fid_LQiP9j9aM7e4KWpE",
                                     "X-Naver-Client-Secret":"6IxM7NZWFK"})
    return result. json()



def call_and_print(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
#     print(json_obj)
    i=1
    for item in json_obj['items']:
        title = item['title']. replace("<b>",""). replace("</b>","")
        print(i,'====>', title + "@"+ item["link"] + "@"+ item["price"])
        i = i+1
        
def call_and_csv_write(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
    print(json_obj)
    for item in json_obj["items"]:
        title = item['title'].replace("<b>","").replace("</b>","")
        wr. writerow([title, item["link"], item["price"]])
        
        
keyword = input("검색어를 입력하시오. ")

start_point = int(input("시작 포인트를 입력하시오. "))
display_count = int(input("한번에 추출하고자 하는 결괏값 수를 입력하시오. "))

repeat_times = int(input("결과 추출을 반복할 횟수를 입력하시오. "))


#======== 출력하기 =======

f = open('book_api.csv', 'w', encoding = 'utf-8-sig', newline='')
wr = csv.writer(f)

for cnt in range(1,repeat_times+1):
    print('--- { count } ---------', cnt)
    call_and_print(keyword,display_count,start_point)
    call_and_csv_write(keyword, display_count, start_point)
    start_point += display_count

f.close()
json_obj = get_api_result(keyword, display_count, start_point)

#--------------------------------------------------------------


f = open('book_api.csv', 'r', encoding = 'utf-8-sig', newline='')
rdr = csv.reader(f)
cnt = 0

for line in rdr:
    cnt += 1
    
print('count: ', cnt)
f.close()
# Out:
# 검색어를 입력하시오. 코로나
# 시작 포인트를 입력하시오. 1
# 한번에 추출하고자 하는 결괏값 수를 입력하시오. 2
# 결과 추출을 반복할 횟수를 입력하시오. 2
# --- { count } --------- 1
# 1 ====> 위드 코로나 2022년 경제전망 (백신 이후 경제를 바꿀 20가지 트렌드)@http://book.naver.com/bookdb/book_detail.php?bid=21122448@18000
# 2 ====> 코로나 미스터리 (팩트와 수치로 분석한 코로나19 오해와 진실)@http://book.naver.com/bookdb/book_detail.php?bid=17603807@15000
# ...

# %%
<뉴스> 크롤링

# %%
import requests
from urllib.parse import urlparse
import csv

def get_api_result(keyword, display, start):
    url = "https://openapi.naver.com/v1/search/news?query="+ keyword +"&display=" + str(display_count) +"&start=" + str(start)
    result = requests. get(urlparse(url). geturl(),
                           headers= {"X-Naver-Client-Id":"Fid_LQiP9j9aM7e4KWpE",
                                     "X-Naver-Client-Secret":"6IxM7NZWFK"})
    return result. json()



def call_and_print(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
#     print(json_obj)
    i=1
    for item in json_obj['items']:
        title = item['title']. replace("<b>",""). replace("</b>","")
        print(i,'====>', title + "@"+ item["originallink"] + "@"+ item["pubDate"])
        i = i+1
        
def call_and_csv_write(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
    print(json_obj)
    for item in json_obj["items"]:
        title = item['title'].replace("<b>","").replace("</b>","")
        wr. writerow([title, item["originallink"], item["pubDate"]])
        
        
keyword = input("검색어를 입력하시오. ")

start_point = int(input("시작 포인트를 입력하시오. "))
display_count = int(input("한번에 추출하고자 하는 결괏값 수를 입력하시오. "))

repeat_times = int(input("결과 추출을 반복할 횟수를 입력하시오. "))


#======== 출력하기 =======

f = open('news_api.csv', 'w', encoding = 'utf-8-sig', newline='')
wr = csv.writer(f)

for cnt in range(1,repeat_times+1):
    print('--- { count } ---------', cnt)
    call_and_print(keyword,display_count,start_point)
    call_and_csv_write(keyword, display_count, start_point)
    start_point += display_count

f.close()
json_obj = get_api_result(keyword, display_count, start_point)

#--------------------------------------------------------------


f = open('news_api.csv', 'r', encoding = 'utf-8-sig', newline='')
rdr = csv.reader(f)
cnt = 0

for line in rdr:
    cnt += 1
    
print('count: ', cnt)
f.close()
# Out:
# 검색어를 입력하시오. 코로나
# 시작 포인트를 입력하시오. 1
# 한번에 추출하고자 하는 결괏값 수를 입력하시오. 2
# 결과 추출을 반복할 횟수를 입력하시오. 2
# --- { count } --------- 1
# 1 ====> 2월8일 동정@https://www.hani.co.kr/arti/society/ngo/1030133.html@Mon, 07 Feb 2022 22:44:00 +0900
# 2 ====> 7일 오후 9시까지 3만1777명 확진, 또 최다 경신…어제보다 4천67명 많아@https://idsn.co.kr/news/view/1065619855810495@Mon, 07 Feb 2022 22:44:00 +0900
# ...

# %%
<영화> 크롤링

# %%
import requests
from urllib.parse import urlparse
import csv

def get_api_result(keyword, display, start):
    url = "https://openapi.naver.com/v1/search/movie?query="+ keyword + "&genre=" + str(genre)+"&display=" + str(display_count) +"&start=" + str(start)
    result = requests. get(urlparse(url). geturl(),
                           headers= {"X-Naver-Client-Id":"Fid_LQiP9j9aM7e4KWpE",
                                     "X-Naver-Client-Secret":"6IxM7NZWFK"})
    return result. json()



def call_and_print(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
#     print(json_obj)
    i=1
    for item in json_obj['items']:
        title = item['title']. replace("<b>",""). replace("</b>","")
        print(i,'====>', title + "@"+ item["link"] + "@"+ item["actor"])
        i = i+1
        
def call_and_csv_write(keyword, display, page):
    json_obj = get_api_result(keyword, display, start_point)
    print(json_obj)
    for item in json_obj["items"]:
        title = item['title'].replace("<b>","").replace("</b>","")
        wr. writerow([title, item["link"], item["actor"]])
        
        
keyword = input("검색어를 입력하시오. ")
print("1: 드라마 2: 판타지 3: 서부 4: 공포5: 로맨스 6: 모험7: 스릴러 8: 느와르9: 컬트 10: 다큐멘터리11: 코미디 12: 가족13: 미스터리 14: 전쟁15: 애니메이션 16: 범죄17: 뮤지컬 18: SF19: 액션20: 무협21: 에로 22: 서스펜스23: 서사 24: 블랙코미디25: 실험 26: 영화카툰27: 영화음악 28: 영화패러디포스터")
genre = input("원하는 장르의 번호는? ")

start_point = int(input("시작 포인트를 입력하시오. "))
display_count = int(input("한번에 추출하고자 하는 결괏값 수를 입력하시오. "))

repeat_times = int(input("결과 추출을 반복할 횟수를 입력하시오. "))


#======== 출력하기 =======

f = open('movie_api.csv', 'w', encoding = 'utf-8-sig', newline='')
wr = csv.writer(f)

for cnt in range(1,repeat_times+1):
    print('--- { count } ---------', cnt)
    call_and_print(keyword,display_count,start_point)
    call_and_csv_write(keyword, display_count, start_point)
    start_point += display_count

f.close()
json_obj = get_api_result(keyword, display_count, start_point)

#--------------------------------------------------------------


f = open('movie_api.csv', 'r', encoding = 'utf-8-sig', newline='')
rdr = csv.reader(f)
cnt = 0

for line in rdr:
    cnt += 1
    
print('count: ', cnt)
f.close()
# Out:
# 검색어를 입력하시오. 사랑
# 1: 드라마 2: 판타지 3: 서부 4: 공포5: 로맨스 6: 모험7: 스릴러 8: 느와르9: 컬트 10: 다큐멘터리11: 코미디 12: 가족13: 미스터리 14: 전쟁15: 애니메이션 16: 범죄17: 뮤지컬 18: SF19: 액션20: 무협21: 에로 22: 서스펜스23: 서사 24: 블랙코미디25: 실험 26: 영화카툰27: 영화음악 28: 영화패러디포스터
# 원하는 장르의 번호는? 21
# 시작 포인트를 입력하시오. 1
# 한번에 추출하고자 하는 결괏값 수를 입력하시오. 2
# 결과 추출을 반복할 횟수를 입력하시오. 2
# --- { count } --------- 1
# 1 ====> 달콤한 새엄마의 입술사랑@https://movie.naver.com/movie/bi/mi/basic.nhn?code=212247@
# 2 ====> 엄친딸 : 2대 1 사랑 나누기@https://movie.naver.com/movie/bi/mi/basic.nhn?code=207692@
# ...
